# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('33.-34.Dataset_2a.csv')
df1
# Out:
#        price  car_ID fueltype  CompanyName aspiration doornumber      carbody  \
# 0    13495.0       1      gas  alfa-romero        std        two  convertible
# 1    16500.0       2      gas  alfa-romero        std        two  convertible
# 2    16500.0       3      gas  alfa-romero        std        two    hatchback
# 3    13950.0       4      gas         audi        std       four        sedan
# 4    17450.0       5      gas         audi        std       four        sedan
# ..       ...     ...      ...          ...        ...        ...          ...
# 200  16845.0     201      gas        volvo        std       four        sedan
# 201  19045.0     202      gas        volvo      turbo       four        sedan
# 202  21485.0     203      gas        volvo        std       four        sedan
# 203  22470.0     204   diesel        volvo      turbo       four        sedan
# 204  22625.0     205      gas        volvo      turbo       four        sedan
#
# ...

# %%
plt.boxplot(df1['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21df2204510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21df2205a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21df21f7350>],
#  'medians': [<matplotlib.lines.Line2D at 0x21df2207210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21df2207950>],
#  'means': []}

# %% [markdown]
# ##IDENTIFYING THE OUTLIERS

# %%
Q1 = df1['price'].quantile(0.25)
Q3 = df1['price'].quantile(0.75)

IQR = Q3-Q1

# %%
df1_clean = df1[(df1["price"] > Q1 - 1.5 * IQR) & (df1["price"] < Q3 + 1.5 * IQR)]

# %%
df1_clean
# Out:
#        price  car_ID fueltype  CompanyName aspiration doornumber      carbody  \
# 0    13495.0       1      gas  alfa-romero        std        two  convertible
# 1    16500.0       2      gas  alfa-romero        std        two  convertible
# 2    16500.0       3      gas  alfa-romero        std        two    hatchback
# 3    13950.0       4      gas         audi        std       four        sedan
# 4    17450.0       5      gas         audi        std       four        sedan
# ..       ...     ...      ...          ...        ...        ...          ...
# 200  16845.0     201      gas        volvo        std       four        sedan
# 201  19045.0     202      gas        volvo      turbo       four        sedan
# 202  21485.0     203      gas        volvo        std       four        sedan
# 203  22470.0     204   diesel        volvo      turbo       four        sedan
# 204  22625.0     205      gas        volvo      turbo       four        sedan
#
# ...

# %%
plt.boxplot(df1_clean['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21df0bc1690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21df21bdd10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21df21e8250>],
#  'medians': [<matplotlib.lines.Line2D at 0x21df22c5750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21df22c5fd0>],
#  'means': []}

# %%
df1_clean
# Out:
#        price  car_ID fueltype  CompanyName aspiration doornumber      carbody  \
# 0    13495.0       1      gas  alfa-romero        std        two  convertible
# 1    16500.0       2      gas  alfa-romero        std        two  convertible
# 2    16500.0       3      gas  alfa-romero        std        two    hatchback
# 3    13950.0       4      gas         audi        std       four        sedan
# 4    17450.0       5      gas         audi        std       four        sedan
# ..       ...     ...      ...          ...        ...        ...          ...
# 200  16845.0     201      gas        volvo        std       four        sedan
# 201  19045.0     202      gas        volvo      turbo       four        sedan
# 202  21485.0     203      gas        volvo        std       four        sedan
# 203  22470.0     204   diesel        volvo      turbo       four        sedan
# 204  22625.0     205      gas        volvo      turbo       four        sedan
#
# ...

# %%
df1_clean['horsepower'].max() , df1_clean['horsepower'].min()
# Out:
# (200, 48)

# %% [markdown]
# ## STANDARDIZING THE VALUES IN THE HORSE POWER COLUMN

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#df1_clean['horsepower'] = scaler.fit_transform(df1_clean['horsepower'].values.reshape(-1, 1))
#df1_clean['price'] = scaler.fit_transform(df1_clean['price'].values.reshape(-1, 1))

# %%
df1_clean['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 190, dtype: float64

# %%
df1_clean
# Out:
#        price  car_ID fueltype  CompanyName aspiration doornumber      carbody  \
# 0    13495.0       1      gas  alfa-romero        std        two  convertible
# 1    16500.0       2      gas  alfa-romero        std        two  convertible
# 2    16500.0       3      gas  alfa-romero        std        two    hatchback
# 3    13950.0       4      gas         audi        std       four        sedan
# 4    17450.0       5      gas         audi        std       four        sedan
# ..       ...     ...      ...          ...        ...        ...          ...
# 200  16845.0     201      gas        volvo        std       four        sedan
# 201  19045.0     202      gas        volvo      turbo       four        sedan
# 202  21485.0     203      gas        volvo        std       four        sedan
# 203  22470.0     204   diesel        volvo      turbo       four        sedan
# 204  22625.0     205      gas        volvo      turbo       four        sedan
#
# ...

# %%
plt.scatter(df1_clean['horsepower'] , df1_clean['price'])

# %% [markdown]
# ## FITTING A REGRESSION LINE TO THE ABOVE PLOT

# %%
from sklearn.linear_model import LinearRegression
reg1 = LinearRegression()
reg1.fit(df1_clean['horsepower'].values.reshape(-1, 1) , df1_clean['price'].values.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
results = reg1.score(df1_clean['horsepower'].values.reshape(-1, 1) , df1_clean['price'].values.reshape(-1, 1))
results
# Out:
# 0.5291015832440316

# %% [markdown]
# ## TRANSFORMING THE VARIABLES

# %%
df1_clean['horsepower_sq'] = df1_clean['horsepower']**2
df1_clean['price_log'] = np.log(df1_clean['price'])
# Out:
# C:\Users\pkgno\AppData\Local\Temp\ipykernel_12528\3546972856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_clean['horsepower_sq'] = df1_clean['horsepower']**2
# C:\Users\pkgno\AppData\Local\Temp\ipykernel_12528\3546972856.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_clean['price_log'] = np.log(df1_clean['price'])

# %%
plt.scatter(df1_clean['horsepower_sq'] , df1_clean['price_log'])

# %%
reg2 = LinearRegression()
reg2.fit(df1_clean['horsepower_sq'].values.reshape(-1, 1) , df1_clean['price_log'].values.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
results2 = reg1.score(df1_clean['horsepower_sq'].values.reshape(-1, 1) , df1_clean['price_log'].values.reshape(-1, 1))
results2
# Out:
# -13232652257058.729

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming reg2 is your LinearRegression model
# Assuming df1_clean is your DataFrame

# Make predictions using the model
df1_clean['price_log_pred'] = reg2.predict(df1_clean['horsepower_sq'].values.reshape(-1, 1))

# Plot the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='horsepower_sq', y='price_log', data=df1_clean, label='Original Data')

# Plot the regression line
sns.lineplot(x='horsepower_sq', y='price_log_pred', data=df1_clean, color='red', label='Regression Line')

plt.xlabel('Horsepower Squared')
plt.ylabel('Log-Transformed Price')
plt.title('Scatter Plot with Regression Line')
plt.legend()
plt.show()
# Out:
# C:\Users\pkgno\AppData\Local\Temp\ipykernel_12528\3663065699.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_clean['price_log_pred'] = reg2.predict(df1_clean['horsepower_sq'].values.reshape(-1, 1))

# %%
from sklearn.metrics import r2_score

y_pred = reg2.predict(df1_clean['horsepower_sq'].values.reshape(-1, 1))

# Calculate R-squared value
r2_value = r2_score(df1_clean['price_log'], y_pred)

print(f'R-squared value: {r2_value}')
# Out:
# R-squared value: 0.5176227806143756

# %%
numeric_cols = df1_clean.select_dtypes(include=['number'])
numeric_cols
# Out:
#        price  car_ID  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0    13495.0       1       88.6      168.8      64.1       48.8        2548
# 1    16500.0       2       88.6      168.8      64.1       48.8        2548
# 2    16500.0       3       94.5      171.2      65.5       52.4        2823
# 3    13950.0       4       99.8      176.6      66.2       54.3        2337
# 4    17450.0       5       99.4      176.6      66.4       54.3        2824
# ..       ...     ...        ...        ...       ...        ...         ...
# 200  16845.0     201      109.1      188.8      68.9       55.5        2952
# 201  19045.0     202      109.1      188.8      68.8       55.5        3049
# 202  21485.0     203      109.1      188.8      68.9       55.5        3012
# 203  22470.0     204      109.1      188.8      68.9       55.5        3217
# 204  22625.0     205      109.1      188.8      68.9       55.5        3062
#
# ...

# %%
sns.heatmap(numeric_cols.corr() , annot=True)
# Out:
# <Axes: >

# %%
numeric_cols['curbweight'].max(), numeric_cols['curbweight'].min()
# Out:
# (3750, 1488)

# %%
mlr = df1_clean[['horsepower' , 'curbweight' , 'carwidth' ]]
clos = ['horsepower' , 'curbweight' , 'carwidth']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
mlr_st = pd.DataFrame(scaler.fit_transform(mlr), columns=mlr.columns)
mlr_st
# Out:
#      horsepower  curbweight  carwidth
# 0      0.456720    0.152836 -0.834337
# 1      0.456720    0.152836 -0.834337
# 2      1.883098    0.771208 -0.073509
# 3      0.158176   -0.321625  0.306906
# 4      0.589406    0.773457  0.415595
# ..          ...         ...       ...
# 185    0.556235    1.061281  1.774217
# 186    2.082127    1.279398  1.719872
# 187    1.219666    1.196199  1.774217
# 188    0.290862    1.657168  1.774217
# 189    0.556235    1.308630  1.774217
#
# [190 rows x 3 columns]

# %%
y = numeric_cols['price']

# %%
reg3 = LinearRegression()
model3 = reg3.fit(mlr_st , y)
model3
# Out:
# LinearRegression()

# %%
import seaborn as sns

# Get predicted values
y_pred = model3.predict(mlr_st)

# Create a residual plot
sns.residplot(x=y_pred, y=y, lowess=True, line_kws={'color': 'red'})
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[85], line 7
#       4 y_pred = model3.predict(mlr_st)
#       6 # Create a residual plot
# ----> 7 sns.residplot(x=y_pred, y=y, lowess=True, line_kws={'color': 'red'})
#       8 plt.xlabel('Predicted Values')
#       9 plt.ylabel('Residuals')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\seaborn\regression.py:939, in residplot(data, x, y, x_partial, y_partial, lowess, order, robust, dropna, label, color, scatter_kws, line_kws, ax)
#     937 scatter_kws = {} if scatter_kws is None else scatter_kws.copy()
#     938 line_kws = {} if line_kws is None else line_kws.copy()
# --> 939 plotter.plot(ax, scatter_kws, line_kws)
#     940 return ax
#
# File ~\AppData\Roaming\Python\Python311\site-packages\seaborn\regression.py:384, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
# ...

# %%
import statsmodels.api as sm

# Assuming mlr_st is your standardized feature matrix and y is your target variable
X_with_intercept = sm.add_constant(mlr_st)  # Adding a constant term for the intercept

# Create a linear regression model
model = sm.OLS(y, X_with_intercept)

# Fit the model
results = model.fit()

# Get the summary
summary = results.summary()

# Print the summary
print(summary)

# %%
r_squared = model3.score(mlr_st, y)
r_squared
# Out:
# 0.7719022477036317

# %% [markdown]
# ## ANOVA TEST FOR OVERALL MODEL IMPORTANCE

# %%
import statsmodels.api as sm
aov= sm.stats.anova_lm(model3, typ =1)
aov
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 2
#       1 import statsmodels.api as sm
# ----> 2 aov= sm.stats.anova_lm(model3, typ =1)
#       3 aov
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\stats\anova.py:353, in anova_lm(*args, **kwargs)
#     351 if len(args) == 1:
#     352     model = args[0]
# --> 353     return anova_single(model, **kwargs)
#     355 if typ not in [1, "I"]:
#     356     raise ValueError("Multiple models only supported for type I. "
#     357                      "Got type %s" % str(typ))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\statsmodels\stats\anova.py:65, in anova_single(model, **kwargs)
#      62 if robust:
#      63     robust = robust.lower()
# ---> 65 endog = model.model.endog
#      66 exog = model.model.exog
#      67 nobs = exog.shape[0]
#
# ...

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
from scipy.stats import f

# Assuming mlr_st is your standardized feature matrix and y is your target variable
reg3 = LinearRegression()
model3 = reg3.fit(mlr_st, y)

# Number of observations
n = len(y)

# Number of predictors
p = mlr_st.shape[1]

# Degrees of freedom for the numerator (df_regression)
df_regression = p - 1

# Degrees of freedom for the denominator (df_residual)
df_residual = n - p

# Calculate the F-statistic
f_statistic = (np.sum((model3.predict(mlr_st) - np.mean(y))**2) / df_regression) / (np.sum((y - model3.predict(mlr_st))**2) / df_residual)

# Calculate the p-value
p_value = 1 - f.cdf(f_statistic, df_regression, df_residual)

print("F-statistic:", f_statistic)
print("p-value:", p_value)
# Out:
# F-statistic: 316.41197439997177
# p-value: 1.1102230246251565e-16
